# %% [markdown]
# Scenario 3: Multiple data scientists working on multiple ML models <br>
# MLflow setup: <br>
#
# Tracking server: yes, remote server (EC2). <br>
# Backend store: postgresql database. <br>
# Artifacts store: s3 bucket. <br>
#
# The experiments can be explored by accessing the remote server.
#
# The exampe uses AWS to host a remote server. In order to run the example you'll need an AWS account. Follow the steps described in the file mlflow_on_aws.md to create a new AWS account and launch the tracking server.

# %%
import mlflow
import os

os.environ["AWS_PROFILE"] = "personal_gmail" # fill in with your AWS profile. More info: https://docs.aws.amazon.com/sdk-for-java/latest/developer-guide/setup.html#setup-credentials

TRACKING_SERVER_HOST = "ec2-34-227-25-167.compute-1.amazonaws.com" # fill in with the public DNS of the EC2 instance
mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:5000")

# %%
mlflow.get_tracking_uri()
# Out:
# 'http://ec2-34-227-25-167.compute-1.amazonaws.com:5000'

# %%
mlflow.search_experiments()
# Out:
# [<Experiment: artifact_location='s3://mlflow-artifact-tracking-bucket/0', creation_time=1750181149745, experiment_id='0', last_update_time=1750181149745, lifecycle_stage='active', name='Default', tags={}>]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

mlflow.set_experiment("my-experiment-1")

with mlflow.start_run():

    X, y = load_iris(return_X_y=True)

    params = {"C": 0.1, "random_state": 42}
    mlflow.log_params(params)

    lr = LogisticRegression(**params).fit(X, y)
    y_pred = lr.predict(X)
    mlflow.log_metric("accuracy", accuracy_score(y, y_pred))

    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# 2025/06/17 17:37:33 INFO mlflow.tracking.fluent: Experiment with name 'my-experiment-1' does not exist. Creating a new experiment.
# 2025/06/17 17:37:43 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run worried-auk-851 at: http://ec2-34-227-25-167.compute-1.amazonaws.com:5000/#/experiments/1/runs/10366c4bf668441dbbd37373f77f9fbb
# 🧪 View experiment at: http://ec2-34-227-25-167.compute-1.amazonaws.com:5000/#/experiments/1
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# Cell In[4], line 18
#      15 y_pred = lr.predict(X)
#      16 mlflow.log_metric("accuracy", accuracy_score(y, y_pred))
# ---> 18 mlflow.sklearn.log_model(lr, artifact_path="models")
#      19 print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
#
# File ~/miniconda3/lib/python3.13/site-packages/mlflow/sklearn/__init__.py:413, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata)
#     334 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     335 def log_model(
#     336     sk_model,
#    (...)    348     metadata=None,
#     349 ):
#     350     """
#     351     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     352     containing the following flavors:
#    (...)    411
#     412     """
# --> 413     return Model.log(
#     414         artifact_path=artifact_path,
#     415         flavor=mlflow.sklearn,
#     416         sk_model=sk_model,
#     417         conda_env=conda_env,
#     418         code_paths=code_paths,
#     419         serialization_format=serialization_format,
#     420         registered_model_name=registered_model_name,
#     421         signature=signature,
#     422         input_example=input_example,
#     423         await_registration_for=await_registration_for,
#     424         pip_requirements=pip_requirements,
#     425         extra_pip_requirements=extra_pip_requirements,
#     426         pyfunc_predict_fn=pyfunc_predict_fn,
#     427         metadata=metadata,
#     428     )
#
# File ~/miniconda3/lib/python3.13/site-packages/mlflow/models/model.py:921, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, **kwargs)
#     918     for prompt in prompts:
#     919         client.log_prompt(run_id, prompt)
# --> 921 mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path, run_id)
#     923 # if the model_config kwarg is passed in, then log the model config as an params
#     924 if model_config := kwargs.get("model_config"):
#
# File ~/miniconda3/lib/python3.13/site-packages/mlflow/tracking/fluent.py:1219, in log_artifacts(local_dir, artifact_path, run_id)
#    1185 """
#    1186 Log all the contents of a local directory as artifacts of the run. If no run is active,
#    1187 this method will create a new active run.
#    (...)   1216             mlflow.log_artifacts(tmp_dir, artifact_path="states")
#    1217 """
#    1218 run_id = run_id or _get_or_start_run().info.run_id
# -> 1219 MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#
# File ~/miniconda3/lib/python3.13/site-packages/mlflow/tracking/client.py:2428, in MlflowClient.log_artifacts(self, run_id, local_dir, artifact_path)
#    2381 def log_artifacts(
#    2382     self, run_id: str, local_dir: str, artifact_path: Optional[str] = None
#    2383 ) -> None:
#    2384     """Write a directory of files to the remote ``artifact_uri``.
#    2385
#    2386     Args:
#    (...)   2426
#    2427     """
# -> 2428     self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#
# File ~/miniconda3/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:968, in TrackingServiceClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     959 def log_artifacts(self, run_id, local_dir, artifact_path=None):
#     960     """Write a directory of files to the remote ``artifact_uri``.
#     961
#     962     Args:
#    (...)    966
#     967     """
# --> 968     self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#
# File ~/miniconda3/lib/python3.13/site-packages/mlflow/store/artifact/s3_artifact_repo.py:194, in S3ArtifactRepository.log_artifacts(self, local_dir, artifact_path)
#     191     upload_path = posixpath.join(dest_path, rel_path)
#     193 for f in filenames:
# --> 194     self._upload_file(
#     195         s3_client=s3_client,
#     196         local_file=os.path.join(root, f),
#     197         bucket=bucket,
#     198         key=posixpath.join(upload_path, f),
#     199     )
#
# File ~/miniconda3/lib/python3.13/site-packages/mlflow/store/artifact/s3_artifact_repo.py:169, in S3ArtifactRepository._upload_file(self, s3_client, local_file, bucket, key)
#     167 if environ_extra_args is not None:
#     168     extra_args.update(environ_extra_args)
# --> 169 s3_client.upload_file(Filename=local_file, Bucket=bucket, Key=key, ExtraArgs=extra_args)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/boto3/s3/inject.py:175, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     140 """Upload a file to an S3 object.
#     141
#     142 Usage::
#    (...)    172     transfer.
#     173 """
#     174 with S3Transfer(self, Config) as transfer:
# --> 175     return transfer.upload_file(
#     176         filename=Filename,
#     177         bucket=Bucket,
#     178         key=Key,
#     179         extra_args=ExtraArgs,
#     180         callback=Callback,
#     181     )
#
# File ~/miniconda3/lib/python3.13/site-packages/boto3/s3/transfer.py:372, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     368 future = self._manager.upload(
#     369     filename, bucket, key, extra_args, subscribers
#     370 )
#     371 try:
# --> 372     future.result()
#     373 # If a client error was raised, add the backwards compatibility layer
#     374 # that raises a S3UploadFailedError. These specific errors were only
#     375 # ever thrown for upload_parts but now can be thrown for any related
#     376 # client error.
#     377 except ClientError as e:
#
# File ~/miniconda3/lib/python3.13/site-packages/s3transfer/futures.py:111, in TransferFuture.result(self)
#     106 def result(self):
#     107     try:
#     108         # Usually the result() method blocks until the transfer is done,
#     109         # however if a KeyboardInterrupt is raised we want want to exit
#     110         # out of this and propagate the exception.
# --> 111         return self._coordinator.result()
#     112     except KeyboardInterrupt as e:
#     113         self.cancel()
#
# File ~/miniconda3/lib/python3.13/site-packages/s3transfer/futures.py:287, in TransferCoordinator.result(self)
#     284 # Once done waiting, raise an exception if present or return the
#     285 # final result.
#     286 if self._exception:
# --> 287     raise self._exception
#     288 return self._result
#
# File ~/miniconda3/lib/python3.13/site-packages/s3transfer/tasks.py:142, in Task.__call__(self, ctx)
#     138     # If the task is not done (really only if some other related
#     139     # task to the TransferFuture had failed) then execute the task's
#     140     # main() method.
#     141     if not self._transfer_coordinator.done():
# --> 142         return self._execute_main(kwargs)
#     143 except Exception as e:
#     144     self._log_and_set_exception(e)
#
# File ~/miniconda3/lib/python3.13/site-packages/s3transfer/tasks.py:165, in Task._execute_main(self, kwargs)
#     162 # Log what is about to be executed.
#     163 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 165 return_value = self._main(**kwargs)
#     166 # If the task is the final task, then set the TransferFuture's
#     167 # value to the return value from main().
#     168 if self._is_final:
#
# File ~/miniconda3/lib/python3.13/site-packages/s3transfer/upload.py:796, in PutObjectTask._main(self, client, fileobj, bucket, key, extra_args)
#     787 """
#     788 :param client: The client to use when calling PutObject
#     789 :param fileobj: The file to upload.
#    (...)    793     used in the upload.
#     794 """
#     795 with fileobj as body:
# --> 796     client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/client.py:598, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     594     raise TypeError(
#     595         f"{py_operation_name}() only accepts keyword arguments."
#     596     )
#     597 # The "self" in this scope is referring to the BaseClient.
# --> 598 return self._make_api_call(operation_name, kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/client.py:1043, in BaseClient._make_api_call(self, operation_name, api_params)
#    1039     maybe_compress_request(
#    1040         self.meta.config, request_dict, operation_model
#    1041     )
#    1042     apply_request_checksum(request_dict)
# -> 1043     http, parsed_response = self._make_request(
#    1044         operation_model, request_dict, request_context
#    1045     )
#    1047 self.meta.events.emit(
#    1048     f'after-call.{service_id}.{operation_name}',
#    1049     http_response=http,
#    (...)   1052     context=request_context,
#    1053 )
#    1055 if http.status_code >= 300:
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/client.py:1067, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1065 def _make_request(self, operation_model, request_dict, request_context):
#    1066     try:
# -> 1067         return self._endpoint.make_request(operation_model, request_dict)
#    1068     except Exception as e:
#    1069         self.meta.events.emit(
#    1070             f'after-call-error.{self._service_model.service_id.hyphenize()}.{operation_model.name}',
#    1071             exception=e,
#    1072             context=request_context,
#    1073         )
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/endpoint.py:196, in Endpoint._send_request(self, request_dict, operation_model)
#     194 context = request_dict['context']
#     195 self._update_retries_context(context, attempts)
# --> 196 request = self.create_request(request_dict, operation_model)
#     197 success_response, exception = self._get_response(
#     198     request, operation_model, context
#     199 )
#     200 while self._needs_retry(
#     201     attempts,
#     202     operation_model,
#    (...)    205     exception,
#     206 ):
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/endpoint.py:132, in Endpoint.create_request(self, params, operation_model)
#     130     service_id = operation_model.service_model.service_id.hyphenize()
#     131     event_name = f'request-created.{service_id}.{operation_model.name}'
# --> 132     self._event_emitter.emit(
#     133         event_name,
#     134         request=request,
#     135         operation_name=operation_model.name,
#     136     )
#     137 prepared_request = self.prepare_request(request)
#     138 return prepared_request
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/hooks.py:412, in EventAliaser.emit(self, event_name, **kwargs)
#     410 def emit(self, event_name, **kwargs):
#     411     aliased_event_name = self._alias_event_name(event_name)
# --> 412     return self._emitter.emit(aliased_event_name, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/hooks.py:256, in HierarchicalEmitter.emit(self, event_name, **kwargs)
#     245 def emit(self, event_name, **kwargs):
#     246     """
#     247     Emit an event by name with arguments passed as keyword args.
#     248
#    (...)    254              handlers.
#     255     """
# --> 256     return self._emit(event_name, kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/hooks.py:239, in HierarchicalEmitter._emit(self, event_name, kwargs, stop_on_response)
#     237 for handler in handlers_to_call:
#     238     logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 239     response = handler(**kwargs)
#     240     responses.append((handler, response))
#     241     if stop_on_response and response is not None:
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/signers.py:106, in RequestSigner.handler(self, operation_name, request, **kwargs)
#     101 def handler(self, operation_name=None, request=None, **kwargs):
#     102     # This is typically hooked up to the "request-created" event
#     103     # from a client's event emitter.  When a new request is created
#     104     # this method is invoked to sign the request.
#     105     # Don't call this method directly.
# --> 106     return self.sign(operation_name, request)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/signers.py:198, in RequestSigner.sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     195     else:
#     196         raise e
# --> 198 auth.add_auth(request)
#
# File ~/miniconda3/lib/python3.13/site-packages/botocore/auth.py:424, in SigV4Auth.add_auth(self, request)
#     422 def add_auth(self, request):
#     423     if self.credentials is None:
# --> 424         raise NoCredentialsError()
#     425     datetime_now = datetime.datetime.utcnow()
#     426     request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %%
mlflow.search_experiments()
